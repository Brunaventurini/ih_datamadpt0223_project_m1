# %%
#Importing and requesting API info.
import pandas as pd 
import numpy as np
from geopy import distance
import requests
import shapely
from shapely.geometry import Point
import geopandas as gpd
response_API = requests.get('https://datos.madrid.es/egob/catalogo/212769-0-atencion-medica.json')
response_API
# Out:
# <Response [200]>

# %%
def cleanTxt(text):
    # Use regular expressions to split the text by "/"
    cleaned_text = re.split('/', text)
    # Return the cleaned text as a list
    x = cleaned_text[-1]
    z = re.split('(?<=.)(?=[A-Z])', x)
    # Return the cleaned text as a space-delimited string
    return " ".join(z)

espacios_df["type"] = espacios_df["@type"].apply(cleanTxt)
espacios_df
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4    https://datos.madrid.es/egob/catalogo/tipo/ent...
# ..                                                 ...
# 265  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 266  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 267  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 268  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 269  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                  @type       id  \
# 0    https://datos.madrid.es/egob/kos/entidadesYorg...   134929
# 1    https://datos.madrid.es/egob/kos/entidadesYorg...    53123
# 2    https://datos.madrid.es/egob/kos/entidadesYorg...    11867
# 3    https://datos.madrid.es/egob/kos/entidadesYorg...    11887
# 4    https://datos.madrid.es/egob/kos/entidadesYorg...    11862
# ..                                                 ...      ...
# 265  https://datos.madrid.es/egob/kos/entidadesYorg...     8835
# 266  https://datos.madrid.es/egob/kos/entidadesYorg...  7318822
# 267  https://datos.madrid.es/egob/kos/entidadesYorg...  7318897
# 268  https://datos.madrid.es/egob/kos/entidadesYorg...  4795428
# 269  https://datos.madrid.es/egob/kos/entidadesYorg...     9154
#
#                                                  title  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 265    Servicio de Inmunoprofilaxis de la Rabia Humana
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                         Vithas Madrid Arturo Soria
#
#                                               relation  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 265  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 266  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 267  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 268  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 269  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                   address.district.@id  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...
# ..                                                 ...
# 265  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                       address.area.@id address.locality  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# ..                                                 ...              ...
# 265  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#     address.postal-code                        address.street-address  \
# 0                 28002                       CALLE SANTA HORTENSIA 1
# 1                 28011                              AVENIDA PORTUGAL
# 2                 28045                              PASEO CHOPERA 12
# 3                 28043                                CALLE MINAYA 7
# 4                 28047                             CALLE CAMARENA 10
# ..                  ...                                           ...
# 265               28006                              CALLE MONTESA 22
# 266               28035                       CALLE CANDIDO MATEOS 11
# 267               28029                             CALLE AGUILEÑAS 1
# 268               28008  PASEO REY 36 Junto al albergue de San Isidro
# 269               28043                        CALLE ARTURO SORIA 103
#
#      location.latitude  location.longitude  \
# 0            40.446053           -3.670277
# 1            40.416331           -3.723991
# 2            40.393057           -3.698067
# 3            40.468289           -3.636150
# 4            40.395971           -3.756272
# ..                 ...                 ...
# 265          40.428977           -3.672161
# 266          40.472772           -3.718133
# 267          40.465481           -3.693638
# 268          40.420548           -3.717966
# 269          40.450507           -3.652268
#
#                         organization.organization-desc  \
# 0    El CCAD Cáritas que forma parte de la red del ...
# 1    El CCAD  Casa de Campo que forma parte de la r...
# 2     Forma de acceso: directo, a través de los ser...
# 3     Acceso: directo, a través de los servicios mu...
# 4     Acceso: directo, a traves de los servicios mu...
# ..                                                 ...
# 265    Metro: Manuel BecerraBus: 1 , 2 , 12 , 21 , ...
# 266    Metro: Antonio Machado (línea 7)  Bus: 42, 1...
# 267    Metro: Valdeacederas (línea 1), Plaza de Cas...
# 268
# 269    Metro: Arturo Soria (línea 4).  Bus: 11, 122...
#
#     organization.accesibility  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 265                         1
# 266                         3
# 267                         3
# 268                         1
# 269                         3
#
#                                  organization.schedule  \
# 0    De lunes a viernes mañanas de 9 a 14 horas, ta...
# 1                   De lunes a viernes de 9 a 17 horas
# 2    Horario ordinario:   De septiembre a junio:   ...
# 3    Horario ordinario:   De septiembre a junio:   ...
# 4    Horario ordinario:   De septiembre a junio:   ...
# ..                                                 ...
# 265                 De lunes a viernes de 9 a 14 horas
# 266                         Consultar telefónicamente.
# 267                         Consultal telefónicamente.
# 268  De lunes a viernes de 11:30 a 14 horas Sábado,...
# 269
#
#                                  organization.services  \
# 0    Valoración interdisciplinar del/de la paciente...
# 1    Valoración interdisciplinar del paciente. Trat...
# 2    Valoración por equipo interdisciplinar Tratami...
# 3    Valoración por equipo interdisciplinar Tratami...
# 4    Valoración por equipo interdisciplinar Tratami...
# ..                                                 ...
# 265  Vacunación antirrábica preexposición (viajeros...
# 266  Atención especializada ambulatoria de salud me...
# 267  Atención especializada ambulatoria de salud me...
# 268  &amp;ldquo;Madroño&amp;rdquo; es un dispositiv...
# 269
#
#                         organization.organization-name  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 265    Servicio de Inmunoprofilaxis de la Rabia Humana
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                         Vithas Madrid Arturo Soria
#
#                                      type
# 0    Centros Asistencia Drogodependientes
# 1    Centros Asistencia Drogodependientes
# 2    Centros Asistencia Drogodependientes
# 3    Centros Asistencia Drogodependientes
# 4    Centros Asistencia Drogodependientes
# ..                                    ...
# 265       Centros Prevencion Enfermedades
# 266                  Centros Salud Mental
# 267                  Centros Salud Mental
# 268  Centros Asistencia Drogodependientes
# 269        Hospitales Clinicas Sanatorios
#
# [270 rows x 18 columns]

# %%
url = 'https://datos.madrid.es/egob/catalogo/212769-0-atencion-medica.json' 
headers = {'Accept': 'application/json'}
espacios_json = requests.get('https://datos.madrid.es/egob/catalogo/212769-0-atencion-medica.json', headers=headers).json()
espacios_df = pd.json_normalize(espacios_json, ['@graph'])

#using the function below to get place type from the @type column
def cleanTxt(text):
    # Use regular expressions to split the text by "/"
    cleaned_text = re.split('/', text)
    # Return the cleaned text as a list
    x = cleaned_text[-1]
    z = re.split('(?<=.)(?=[A-Z])', x)
    # Return the cleaned text as a space-delimited string
    return " ".join(z)

espacios_df["type.place"] = espacios_df["@type"].apply(cleanTxt)

espacios_df
# Out:
#                                                    @id  \
# 0    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3    https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4    https://datos.madrid.es/egob/catalogo/tipo/ent...
# ..                                                 ...
# 265  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 266  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 267  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 268  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 269  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                  @type       id  \
# 0    https://datos.madrid.es/egob/kos/entidadesYorg...   134929
# 1    https://datos.madrid.es/egob/kos/entidadesYorg...    53123
# 2    https://datos.madrid.es/egob/kos/entidadesYorg...    11867
# 3    https://datos.madrid.es/egob/kos/entidadesYorg...    11887
# 4    https://datos.madrid.es/egob/kos/entidadesYorg...    11862
# ..                                                 ...      ...
# 265  https://datos.madrid.es/egob/kos/entidadesYorg...     8835
# 266  https://datos.madrid.es/egob/kos/entidadesYorg...  7318822
# 267  https://datos.madrid.es/egob/kos/entidadesYorg...  7318897
# 268  https://datos.madrid.es/egob/kos/entidadesYorg...  4795428
# 269  https://datos.madrid.es/egob/kos/entidadesYorg...     9154
#
#                                                  title  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 265    Servicio de Inmunoprofilaxis de la Rabia Humana
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                         Vithas Madrid Arturo Soria
#
#                                               relation  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 265  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 266  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 267  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 268  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 269  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                   address.district.@id  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...
# ..                                                 ...
# 265  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                       address.area.@id address.locality  \
# 0    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 3    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 4    https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# ..                                                 ...              ...
# 265  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 266  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 267  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 268  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 269  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#     address.postal-code                        address.street-address  \
# 0                 28002                       CALLE SANTA HORTENSIA 1
# 1                 28011                              AVENIDA PORTUGAL
# 2                 28045                              PASEO CHOPERA 12
# 3                 28043                                CALLE MINAYA 7
# 4                 28047                             CALLE CAMARENA 10
# ..                  ...                                           ...
# 265               28006                              CALLE MONTESA 22
# 266               28035                       CALLE CANDIDO MATEOS 11
# 267               28029                             CALLE AGUILEÑAS 1
# 268               28008  PASEO REY 36 Junto al albergue de San Isidro
# 269               28043                        CALLE ARTURO SORIA 103
#
#      location.latitude  location.longitude  \
# 0            40.446053           -3.670277
# 1            40.416331           -3.723991
# 2            40.393057           -3.698067
# 3            40.468289           -3.636150
# 4            40.395971           -3.756272
# ..                 ...                 ...
# 265          40.428977           -3.672161
# 266          40.472772           -3.718133
# 267          40.465481           -3.693638
# 268          40.420548           -3.717966
# 269          40.450507           -3.652268
#
#                         organization.organization-desc  \
# 0    El CCAD Cáritas que forma parte de la red del ...
# 1    El CCAD  Casa de Campo que forma parte de la r...
# 2     Forma de acceso: directo, a través de los ser...
# 3     Acceso: directo, a través de los servicios mu...
# 4     Acceso: directo, a traves de los servicios mu...
# ..                                                 ...
# 265    Metro: Manuel BecerraBus: 1 , 2 , 12 , 21 , ...
# 266    Metro: Antonio Machado (línea 7)  Bus: 42, 1...
# 267    Metro: Valdeacederas (línea 1), Plaza de Cas...
# 268
# 269    Metro: Arturo Soria (línea 4).  Bus: 11, 122...
#
#     organization.accesibility  \
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
# ..                        ...
# 265                         1
# 266                         3
# 267                         3
# 268                         1
# 269                         3
#
#                                  organization.schedule  \
# 0    De lunes a viernes mañanas de 9 a 14 horas, ta...
# 1                   De lunes a viernes de 9 a 17 horas
# 2    Horario ordinario:   De septiembre a junio:   ...
# 3    Horario ordinario:   De septiembre a junio:   ...
# 4    Horario ordinario:   De septiembre a junio:   ...
# ..                                                 ...
# 265                 De lunes a viernes de 9 a 14 horas
# 266                         Consultar telefónicamente.
# 267                         Consultal telefónicamente.
# 268  De lunes a viernes de 11:30 a 14 horas Sábado,...
# 269
#
#                                  organization.services  \
# 0    Valoración interdisciplinar del/de la paciente...
# 1    Valoración interdisciplinar del paciente. Trat...
# 2    Valoración por equipo interdisciplinar Tratami...
# 3    Valoración por equipo interdisciplinar Tratami...
# 4    Valoración por equipo interdisciplinar Tratami...
# ..                                                 ...
# 265  Vacunación antirrábica preexposición (viajeros...
# 266  Atención especializada ambulatoria de salud me...
# 267  Atención especializada ambulatoria de salud me...
# 268  &amp;ldquo;Madroño&amp;rdquo; es un dispositiv...
# 269
#
#                         organization.organization-name  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 265    Servicio de Inmunoprofilaxis de la Rabia Humana
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                         Vithas Madrid Arturo Soria
#
#                                type.place
# 0    Centros Asistencia Drogodependientes
# 1    Centros Asistencia Drogodependientes
# 2    Centros Asistencia Drogodependientes
# 3    Centros Asistencia Drogodependientes
# 4    Centros Asistencia Drogodependientes
# ..                                    ...
# 265       Centros Prevencion Enfermedades
# 266                  Centros Salud Mental
# 267                  Centros Salud Mental
# 268  Centros Asistencia Drogodependientes
# 269        Hospitales Clinicas Sanatorios
#
# [270 rows x 18 columns]

# %%
#espacios_df = pd.json_normalize(espacios_json, ['@graph'])
#espacios_df = espacios_df[['@id','@type','id','relation','address.district.@id','address.area.@id','address.locality','organization.organization-desc','organization.accesibility','organization.schedule','organization.services']].drop

new_data_frame = pd.DataFrame()
new_data_frame["Place Of Interest"] = espacios_df[["title"]]
new_data_frame["Type Of Place"] = espacios_df[['organization.organization-name']]
new_data_frame["Place Address"] = espacios_df[['address.street-address']]
new_data_frame["Lat_start"] = espacios_df[["location.latitude"]]
new_data_frame["Long_start"] = espacios_df[["location.longitude"]]
new_data_frame["Type of place"] = espacios_df[["type.place"]]
new_data_frame["X,Y"] = new_data_frame["Lat_start"].astype(str) +","+ new_data_frame["Long_start"].astype(str)

#new_data_frame["BiciMad station"] = ###

new_data_frame
# Out:
#                                      Place Of Interest  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 265    Servicio de Inmunoprofilaxis de la Rabia Humana
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                         Vithas Madrid Arturo Soria
#
#                                          Type Of Place  \
# 0    Centro Concertado de Atención a las Adicciones...
# 1    Centro Concertado de Atención a las Adicciones...
# 2    Centro de Atención a las Adicciones (CAD) de A...
# 3    Centro de Atención a las Adicciones (CAD) de H...
# 4    Centro de Atención a las Adicciones (CAD) de L...
# ..                                                 ...
# 265    Servicio de Inmunoprofilaxis de la Rabia Humana
# 266  Unidad de Salud Mental de niños y adolescentes...
# 267  Unidad de Salud Mental de niños y adolescentes...
# 268                               Unidad móvil Madroño
# 269                         Vithas Madrid Arturo Soria
#
#                                     Place Address  Lat_start  Long_start  \
# 0                         CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 1                                AVENIDA PORTUGAL  40.416331   -3.723991
# 2                                PASEO CHOPERA 12  40.393057   -3.698067
# 3                                  CALLE MINAYA 7  40.468289   -3.636150
# 4                               CALLE CAMARENA 10  40.395971   -3.756272
# ..                                            ...        ...         ...
# 265                              CALLE MONTESA 22  40.428977   -3.672161
# 266                       CALLE CANDIDO MATEOS 11  40.472772   -3.718133
# 267                             CALLE AGUILEÑAS 1  40.465481   -3.693638
# 268  PASEO REY 36 Junto al albergue de San Isidro  40.420548   -3.717966
# 269                        CALLE ARTURO SORIA 103  40.450507   -3.652268
#
#                             Type of place  \
# 0    Centros Asistencia Drogodependientes
# 1    Centros Asistencia Drogodependientes
# 2    Centros Asistencia Drogodependientes
# 3    Centros Asistencia Drogodependientes
# 4    Centros Asistencia Drogodependientes
# ..                                    ...
# 265       Centros Prevencion Enfermedades
# 266                  Centros Salud Mental
# 267                  Centros Salud Mental
# 268  Centros Asistencia Drogodependientes
# 269        Hospitales Clinicas Sanatorios
#
#                                         X,Y
# 0    40.446053313442704,-3.6702766124516515
# 1     40.41633059885888,-3.7239914257003304
# 2     40.39305745803064,-3.6980673403694104
# 3     40.468288815918534,-3.636150078507109
# 4     40.39597072367931,-3.7562716852987847
# ..                                      ...
# 265  40.428976927386806,-3.6721607026353884
# 266     40.47277245807722,-3.71813267268184
# 267   40.46548064796593,-3.6936383781020643
# 268   40.42054836583698,-3.7179660205926224
# 269   40.45050723288199,-3.6522677484992117
#
# [270 rows x 7 columns]

# %%
import duckdb
conn = duckdb.connect("./data/bicimad_data.db",read_only = True)

# %%
df2 = conn.execute("SELECT * FROM bicimad_stations").fetch_df()
df2["geometry.coordinates"] = df2["geometry.coordinates"].str.replace('[', '').str.replace(']', '')
# Out:
# C:\Users\bfven\AppData\Local\Temp\ipykernel_39420\1496145101.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2["geometry.coordinates"] = df2["geometry.coordinates"].str.replace('[', '').str.replace(']', '')
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida Juan de Herrera frente a la calle Paul...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261  Avenida de la Complutense (Metro Ciudad Univer...         1
# 262          Calle José Antonio Novais frente al nº 12         1
# 263                          Avenida Complutense nº 23         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               1           30           0           0                   0
# 1               1           30           0           0                   0
# 2               1           24           0           0                   0
# 3               0           18           9           9                   0
# 4               0           24          23           1                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           3          19                   0
# 260             0           24           9          14                   0
# 261             0           24          12          10                   0
# 262             0           24          12          10                   0
# 263             0           24           8          16                   0
#
#     geometry.type                   geometry.coordinates
# 0           Point                 -3.7018341, 40.4172137
# 1           Point  -3.701602938060457, 40.41731271011562
# 2           Point                 -3.7058415, 40.4205886
# 3           Point                 -3.7069171, 40.4302937
# 4           Point                 -3.7025875, 40.4285524
# ..            ...                                    ...
# 259         Point                     -3.72997, 40.43896
# 260         Point                     -3.72699, 40.44375
# 261         Point                     -3.72693, 40.44342
# 262         Point                 -3.7272945, 40.4483322
# 263         Point                     -3.72937, 40.45109
#
# [264 rows x 13 columns]

# %%
# dropping null value columns to avoid errors :0       
df2.dropna(inplace = True)

# %%
# new data frame with split value columns
new = df2["geometry.coordinates"].str.split(",", expand = True)

# %%
df2["long_finish"]= new[0].apply(lambda x: x.strip())#.apply(lambda x: x.replace("0       ", "")).apply(lambda x: x.replace("0        ", ""))

# %%
df2["lat_finish"]= new[1].apply(lambda x: x.strip())#.apply(lambda x: x.replace("0       ", "")).apply(lambda x: x.replace("0        ", ""))
df2["lat_finish"]
# Out:
# 0             40.4172137
# 1      40.41731271011562
# 2             40.4205886
# 3             40.4302937
# 4             40.4285524
#              ...
# 259             40.43896
# 260             40.44375
# 261             40.44342
# 262           40.4483322
# 263             40.45109
# Name: lat_finish, Length: 264, dtype: object

# %%
# Dropping old Name columns
#df2.drop(columns =["geometry.coordinates"], inplace = True)

# %%
df2['long_finish'] = df2['long_finish'].astype(float)
df2['lat_finish'] = df2['lat_finish'].astype(float)
# Out:
#       id                          name  light number  \
# 0      1         1a - Puerta del Sol A      3     1a
# 1      2         1b - Puerta del Sol B      3     1b
# 2      3               2 - Miguel Moya      3      2
# 3      4        3 - Plaza Conde Suchil      2      3
# 4      5                  4 - Malasaña      1      4
# ..   ...                           ...    ...    ...
# 259  265                    257 - INEF      0    257
# 260  266  258 - Ciudad Universitaria 1      2    258
# 261  267  259 - Ciudad Universitaria 2      2    259
# 262  268       260 - Facultad Biología      2    260
# 263  269        261 - Facultad Derecho      2    261
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida Juan de Herrera frente a la calle Paul...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261  Avenida de la Complutense (Metro Ciudad Univer...         1
# 262          Calle José Antonio Novais frente al nº 12         1
# 263                          Avenida Complutense nº 23         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               1           30           0           0                   0
# 1               1           30           0           0                   0
# 2               1           24           0           0                   0
# 3               0           18           9           9                   0
# 4               0           24          23           1                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           3          19                   0
# 260             0           24           9          14                   0
# 261             0           24          12          10                   0
# 262             0           24          12          10                   0
# 263             0           24           8          16                   0
#
#     geometry.type                   geometry.coordinates  long_finish  \
# 0           Point                 -3.7018341, 40.4172137    -3.701834
# 1           Point  -3.701602938060457, 40.41731271011562    -3.701603
# 2           Point                 -3.7058415, 40.4205886    -3.705842
# 3           Point                 -3.7069171, 40.4302937    -3.706917
# 4           Point                 -3.7025875, 40.4285524    -3.702587
# ..            ...                                    ...          ...
# 259         Point                     -3.72997, 40.43896    -3.729970
# 260         Point                     -3.72699, 40.44375    -3.726990
# 261         Point                     -3.72693, 40.44342    -3.726930
# 262         Point                 -3.7272945, 40.4483322    -3.727295
# 263         Point                     -3.72937, 40.45109    -3.729370
#
#      lat_finish
# 0     40.417214
# 1     40.417313
# 2     40.420589
# 3     40.430294
# 4     40.428552
# ..          ...
# 259   40.438960
# 260   40.443750
# 261   40.443420
# 262   40.448332
# 263   40.451090
#
# [264 rows x 15 columns]

# %%
#aqui embaixo eu to pegando new_data_frame (a la de cima) que tem lat_finish e long_finish e mergeando com df2 que tb tem lat_finish e long_finish

# %%
dfcross = new_data_frame.merge(df2, how='cross')
dfcross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71280 entries, 0 to 71279
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Place Of Interest     71280 non-null  object
#  1   Type Of Place         71280 non-null  object
#  2   Place Address         71280 non-null  object
#  3   Lat_start             71280 non-null  float64
#  4   Long_start            71280 non-null  float64
#  5   X,Y                   71280 non-null  object
#  6   id                    71280 non-null  int64
#  7   name                  71280 non-null  object
#  8   light                 71280 non-null  int64
#  9   number                71280 non-null  object
#  10  address               71280 non-null  object
#  11  activate              71280 non-null  int64
#  12  no_available          71280 non-null  int64
#  13  total_bases           71280 non-null  int64
#  14  dock_bikes            71280 non-null  int64
#  15  free_bases            71280 non-null  int64
#  16  reservations_count    71280 non-null  int64
#  17  geometry.type         71280 non-null  object
#  18  geometry.coordinates  71280 non-null  object
#  19  long_finish           71280 non-null  float64
#  20  lat_finish            71280 non-null  float64
# dtypes: float64(4), int64(8), object(9)
# memory usage: 12.0+ MB
#                                        Place Of Interest  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro Concertado de Atención a las Adicciones...
# 3      Centro Concertado de Atención a las Adicciones...
# 4      Centro Concertado de Atención a las Adicciones...
# ...                                                  ...
# 71275                         Vithas Madrid Arturo Soria
# 71276                         Vithas Madrid Arturo Soria
# 71277                         Vithas Madrid Arturo Soria
# 71278                         Vithas Madrid Arturo Soria
# 71279                         Vithas Madrid Arturo Soria
#
#                                            Type Of Place  \
# 0      Centro Concertado de Atención a las Adicciones...
# 1      Centro Concertado de Atención a las Adicciones...
# 2      Centro Concertado de Atención a las Adicciones...
# 3      Centro Concertado de Atención a las Adicciones...
# 4      Centro Concertado de Atención a las Adicciones...
# ...                                                  ...
# 71275                         Vithas Madrid Arturo Soria
# 71276                         Vithas Madrid Arturo Soria
# 71277                         Vithas Madrid Arturo Soria
# 71278                         Vithas Madrid Arturo Soria
# 71279                         Vithas Madrid Arturo Soria
#
#                  Place Address  Lat_start  Long_start  \
# 0      CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 1      CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 2      CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 3      CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# 4      CALLE SANTA HORTENSIA 1  40.446053   -3.670277
# ...                        ...        ...         ...
# 71275   CALLE ARTURO SORIA 103  40.450507   -3.652268
# 71276   CALLE ARTURO SORIA 103  40.450507   -3.652268
# 71277   CALLE ARTURO SORIA 103  40.450507   -3.652268
# 71278   CALLE ARTURO SORIA 103  40.450507   -3.652268
# 71279   CALLE ARTURO SORIA 103  40.450507   -3.652268
#
#                                           X,Y   id  \
# 0      40.446053313442704,-3.6702766124516515    1
# 1      40.446053313442704,-3.6702766124516515    2
# 2      40.446053313442704,-3.6702766124516515    3
# 3      40.446053313442704,-3.6702766124516515    4
# 4      40.446053313442704,-3.6702766124516515    5
# ...                                       ...  ...
# 71275   40.45050723288199,-3.6522677484992117  265
# 71276   40.45050723288199,-3.6522677484992117  266
# 71277   40.45050723288199,-3.6522677484992117  267
# 71278   40.45050723288199,-3.6522677484992117  268
# 71279   40.45050723288199,-3.6522677484992117  269
#
#                                name  light number  ... activate  no_available  \
# 0             1a - Puerta del Sol A      3     1a  ...        1             1
# 1             1b - Puerta del Sol B      3     1b  ...        1             1
# 2                   2 - Miguel Moya      3      2  ...        1             1
# 3            3 - Plaza Conde Suchil      2      3  ...        1             0
# 4                      4 - Malasaña      1      4  ...        1             0
# ...                             ...    ...    ...  ...      ...           ...
# 71275                    257 - INEF      0    257  ...        1             0
# 71276  258 - Ciudad Universitaria 1      2    258  ...        1             0
# 71277  259 - Ciudad Universitaria 2      2    259  ...        1             0
# 71278       260 - Facultad Biología      2    260  ...        1             0
# 71279        261 - Facultad Derecho      2    261  ...        1             0
#
#        total_bases  dock_bikes  free_bases  reservations_count  geometry.type  \
# 0               30           0           0                   0          Point
# 1               30           0           0                   0          Point
# 2               24           0           0                   0          Point
# 3               18           9           9                   0          Point
# 4               24          23           1                   0          Point
# ...            ...         ...         ...                 ...            ...
# 71275           24           3          19                   0          Point
# 71276           24           9          14                   0          Point
# 71277           24          12          10                   0          Point
# 71278           24          12          10                   0          Point
# 71279           24           8          16                   0          Point
#
#                         geometry.coordinates long_finish  lat_finish
# 0                     -3.7018341, 40.4172137   -3.701834   40.417214
# 1      -3.701602938060457, 40.41731271011562   -3.701603   40.417313
# 2                     -3.7058415, 40.4205886   -3.705842   40.420589
# 3                     -3.7069171, 40.4302937   -3.706917   40.430294
# 4                     -3.7025875, 40.4285524   -3.702587   40.428552
# ...                                      ...         ...         ...
# 71275                     -3.72997, 40.43896   -3.729970   40.438960
# 71276                     -3.72699, 40.44375   -3.726990   40.443750
# 71277                     -3.72693, 40.44342   -3.726930   40.443420
# 71278                 -3.7272945, 40.4483322   -3.727295   40.448332
# 71279                     -3.72937, 40.45109   -3.729370   40.451090
#
# [71280 rows x 21 columns]

# %%
def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
def distance_meters(lat_start, long_start, lat_finish, long_finish):
    #return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    start = to_mercator(lat_start, long_start)
    finish = to_mercator(lat_finish, long_finish)
    return start.distance(finish)

# %%
dfcross = dfcross[dfcross['Lat_start']>0]
dfcross = dfcross[dfcross['Long_start']<0]

# %%
#aqui a funcao lambda reclama que nao pode trabalhar com float, entao eu to voltando pra str

# %%
dfcross['Lat_start'] = dfcross['Lat_start'].astype(str)
dfcross['Lat_start'] = dfcross['Lat_start'].apply(lambda x: x.replace("0       ", ""))
dfcross['Lat_start'] = dfcross['Lat_start'].astype(float)

# %%
dfcross['Long_start'] = dfcross['Long_start'].astype(str)
dfcross['Long_start'] = dfcross['Long_start'].apply(lambda x: x.replace("0       ", ""))
dfcross['Long_start'] = dfcross['Long_start'].astype(float)

# %%
dfcross['Distance'] = dfcross[['Lat_start','Long_start','lat_finish','long_finish']].apply(lambda x: distance_meters(x[0], x[1], x[2], x[3]), axis = 1)

# %%
dfcross['Distance'] = dfcross[['Lat_start','Long_start','lat_finish','long_finish']].apply(lambda x: distance_meters(x[0], x[1], x[2], x[3]), axis = 1)
df_cross_processed = dfcross[~dfcross['Distance'].isnull()]
df_cross_processed.loc[df_cross_processed.groupby('Place Of Interest').Distance.idxmin()]
X = df_cross_processed.loc[df_cross_processed.groupby('Place Of Interest').Distance.idxmin()]
# Out:
#                                        Place Of Interest  \
# 53983  CMSc Centro Municipal de Salud Comunitaria  Ch...
# 54165  CMSc Centro Municipal de Salud Comunitaria Arg...
# 54610  CMSc Centro Municipal de Salud Comunitaria Car...
# 54669  CMSc Centro Municipal de Salud Comunitaria Centro
# 55148  CMSc Centro Municipal de Salud Comunitaria Ciu...
# ...                                                  ...
# 70107    Servicio de Inmunoprofilaxis de la Rabia Humana
# 70465  Unidad de Salud Mental de niños y adolescentes...
# 70697  Unidad de Salud Mental de niños y adolescentes...
# 70915                               Unidad móvil Madroño
# 71248                         Vithas Madrid Arturo Soria
#
#                                            Type Of Place  \
# 53983  CMSc Centro Municipal de Salud Comunitaria  Ch...
# 54165  CMSc Centro Municipal de Salud Comunitaria Arg...
# 54610  CMSc Centro Municipal de Salud Comunitaria Car...
# 54669  CMSc Centro Municipal de Salud Comunitaria Centro
# 55148  CMSc Centro Municipal de Salud Comunitaria Ciu...
# ...                                                  ...
# 70107    Servicio de Inmunoprofilaxis de la Rabia Humana
# 70465  Unidad de Salud Mental de niños y adolescentes...
# 70697  Unidad de Salud Mental de niños y adolescentes...
# 70915                               Unidad móvil Madroño
# 71248                         Vithas Madrid Arturo Soria
#
#                                       Place Address  Lat_start  Long_start  \
# 53983                          CALLE RAFAEL CALVO 6  40.433532   -3.697083
# 54165         CALLE CONCEJAL BENITO MARTIN LOZANO 1  40.405692   -3.710820
# 54610                   CALLE EUGENIA DE MONTIJO 90  40.378302   -3.748252
# 54669                      CALLE NAVAS DE TOLOSA 10  40.419202   -3.706942
# 55148                   PLAZA DE AGUSTÍN GONZALEZ 1  40.427642   -3.647143
# ...                                             ...        ...         ...
# 70107                              CALLE MONTESA 22  40.428977   -3.672161
# 70465                       CALLE CANDIDO MATEOS 11  40.472772   -3.718133
# 70697                             CALLE AGUILEÑAS 1  40.465481   -3.693638
# 70915  PASEO REY 36 Junto al albergue de San Isidro  40.420548   -3.717966
# 71248                        CALLE ARTURO SORIA 103  40.450507   -3.652268
#
#                                           X,Y   id  \
# 53983   40.43353205080221,-3.6970827354853677  164
# 54165    40.40569156269297,-3.710819612821558   49
# 54610    40.37830205060461,-3.748252006016631  232
# 54669  40.419201879815446,-3.7069422925635527   25
# 55148  40.427642192384596,-3.6471432101293173  242
# ...                                       ...  ...
# 70107  40.428976927386806,-3.6721607026353884  171
# 70465     40.47277245807722,-3.71813267268184  247
# 70697   40.46548064796593,-3.6936383781020643  215
# 70915   40.42054836583698,-3.7179660205926224  132
# 71248   40.45050723288199,-3.6522677484992117  238
#
#                                  name  light number  ... no_available  \
# 53983  125 - General Martínez Campos       2    125  ...            0
# 54165           45 - Puerta de Toledo      2     45  ...            0
# 54610                  224 - Caramuel      0    224  ...            0
# 54669                22 - Jacometrezo      3     22  ...            1
# 55148     234 - Marqués de Corbera 52      1    234  ...            0
# ...                               ...    ...    ...  ...          ...
# 70107        145 - Ortega y Gasset 87      0    145  ...            0
# 70465         239 - Francos Rodríguez      0    239  ...            0
# 70697                   207 - Remonta      2    207  ...            0
# 70915       161 - Paseo de la Florida      1    161  ...            0
# 71248           230 - Carlota O’Neill      2    230  ...            0
#
#        total_bases  dock_bikes  free_bases  reservations_count  geometry.type  \
# 53983           24           8          15                   0          Point
# 54165           21          12           8                   0          Point
# 54610           24           5          17                   1          Point
# 54669           24           0           0                   0          Point
# 55148           24          18           6                   0          Point
# ...            ...         ...         ...                 ...            ...
# 70107           24           1          21                   0          Point
# 70465           24           3          21                   0          Point
# 70697           18          12           6                   0          Point
# 70915           27          18           5                   2          Point
# 71248           24          13          10                   0          Point
#
#                          geometry.coordinates long_finish lat_finish  \
# 53983                   -3.6948626, 40.435285   -3.694863  40.435285
# 54165                  -3.7110513, 40.4070358   -3.711051  40.407036
# 54610   -3.728533714316331, 40.40913630273305   -3.728534  40.409136
# 54669                  -3.7065376, 40.4200783   -3.706538  40.420078
# 55148  -3.651034981803642, 40.426207143200884   -3.651035  40.426207
# ...                                       ...         ...        ...
# 70107                   -3.6712823, 40.429887   -3.671282  40.429887
# 70465   -3.708002730875242, 40.45673408797698   -3.708003  40.456734
# 70697                  -3.6973333, 40.4630277   -3.697333  40.463028
# 70915                  -3.7224983, 40.4219665   -3.722498  40.421967
# 71248   -3.648958444298144, 40.44370542379883   -3.648958  40.443705
#
#           Distance
# 53983   315.299557
# 54165   151.855401
# 54610  4076.820221
# 54669   107.501192
# 55148   462.570390
# ...            ...
# 70107   140.941235
# 70465  2112.951861
# 70697   494.418400
# 70915   529.669171
# 71248   842.363353
#
# [270 rows x 22 columns]

# %%
def replace_numbers(text):
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'-', '', text)
    return text

def clean_sentence(text):
    # Convert all uppercase letters to lowercase
    text = text.lower()
    # Split the text into individual words
    words = text.split()
    # Capitalize the first letter of each word
    title_words = [word.capitalize() for word in words]
    # Join the words back together into a single string
    cleaned_text = " ".join(title_words)
    return cleaned_text

# %%
#df_cross_processed.to_csv('bici2.csv')
BiciMad_CS = pd.DataFrame()
BiciMad_CS ["Place of interest"] = X["Place Of Interest"]
BiciMad_CS ["Type of place (*)"] = X["Type Of Place"]
BiciMad_CS ["Place Address"] = X["Place Address"].apply(clean_sentence)
BiciMad_CS ["BiciMad Station"] = X["name"].apply(replace_numbers)
BiciMad_CS ["Station Location"] = X["address"]
BiciMad_CS
# Out:
#                                        Place of interest  \
# 53983  CMSc Centro Municipal de Salud Comunitaria  Ch...
# 54165  CMSc Centro Municipal de Salud Comunitaria Arg...
# 54610  CMSc Centro Municipal de Salud Comunitaria Car...
# 54669  CMSc Centro Municipal de Salud Comunitaria Centro
# 55148  CMSc Centro Municipal de Salud Comunitaria Ciu...
# ...                                                  ...
# 70107    Servicio de Inmunoprofilaxis de la Rabia Humana
# 70465  Unidad de Salud Mental de niños y adolescentes...
# 70697  Unidad de Salud Mental de niños y adolescentes...
# 70915                               Unidad móvil Madroño
# 71248                         Vithas Madrid Arturo Soria
#
#                                        Type of place (*)  \
# 53983  CMSc Centro Municipal de Salud Comunitaria  Ch...
# 54165  CMSc Centro Municipal de Salud Comunitaria Arg...
# 54610  CMSc Centro Municipal de Salud Comunitaria Car...
# 54669  CMSc Centro Municipal de Salud Comunitaria Centro
# 55148  CMSc Centro Municipal de Salud Comunitaria Ciu...
# ...                                                  ...
# 70107    Servicio de Inmunoprofilaxis de la Rabia Humana
# 70465  Unidad de Salud Mental de niños y adolescentes...
# 70697  Unidad de Salud Mental de niños y adolescentes...
# 70915                               Unidad móvil Madroño
# 71248                         Vithas Madrid Arturo Soria
#
#                                       Place Address  \
# 53983                          Calle Rafael Calvo 6
# 54165         Calle Concejal Benito Martin Lozano 1
# 54610                   Calle Eugenia De Montijo 90
# 54669                      Calle Navas De Tolosa 10
# 55148                   Plaza De Agustín Gonzalez 1
# ...                                             ...
# 70107                              Calle Montesa 22
# 70465                       Calle Candido Mateos 11
# 70697                             Calle Aguileñas 1
# 70915  Paseo Rey 36 Junto Al Albergue De San Isidro
# 71248                        Calle Arturo Soria 103
#
#                   BiciMad Station                      Station Location
# 53983    General Martínez Campos        Calle Fernández de la Hoz nº 29
# 54165            Puerta de Toledo  Glorieta de la Puerta de Toledo nº 1
# 54610                    Caramuel                  Calle Caramuel nº 51
# 54669                 Jacometrezo                Calle Jacometrezo nº 3
# 55148         Marqués de Corbera       Avenida Marqués de Corbera nº 52
# ...                           ...                                   ...
# 70107            Ortega y Gasset            Calle Ortega y Gasset nº 87
# 70465           Francos Rodríguez         Calle Francos Rodríguez nº 62
# 70697                     Remonta                   Calle Azucenas nº 1
# 70915         Paseo de la Florida              Paseo de la Florida nº 8
# 71248             Carlota O’Neill           Calle Carlota O'Neill nº 32
#
# [270 rows x 5 columns]

# %%
csv = 'Closest_Bici_Mad.csv'
BiciMad_CS.to_csv(csv,index=False)
BiciMad_CS
# Out:
#                                        Place of interest  \
# 53983  CMSc Centro Municipal de Salud Comunitaria  Ch...
# 54165  CMSc Centro Municipal de Salud Comunitaria Arg...
# 54610  CMSc Centro Municipal de Salud Comunitaria Car...
# 54669  CMSc Centro Municipal de Salud Comunitaria Centro
# 55148  CMSc Centro Municipal de Salud Comunitaria Ciu...
# ...                                                  ...
# 70107    Servicio de Inmunoprofilaxis de la Rabia Humana
# 70465  Unidad de Salud Mental de niños y adolescentes...
# 70697  Unidad de Salud Mental de niños y adolescentes...
# 70915                               Unidad móvil Madroño
# 71248                         Vithas Madrid Arturo Soria
#
#                                        Type of place (*)  \
# 53983  CMSc Centro Municipal de Salud Comunitaria  Ch...
# 54165  CMSc Centro Municipal de Salud Comunitaria Arg...
# 54610  CMSc Centro Municipal de Salud Comunitaria Car...
# 54669  CMSc Centro Municipal de Salud Comunitaria Centro
# 55148  CMSc Centro Municipal de Salud Comunitaria Ciu...
# ...                                                  ...
# 70107    Servicio de Inmunoprofilaxis de la Rabia Humana
# 70465  Unidad de Salud Mental de niños y adolescentes...
# 70697  Unidad de Salud Mental de niños y adolescentes...
# 70915                               Unidad móvil Madroño
# 71248                         Vithas Madrid Arturo Soria
#
#                                       Place Address  \
# 53983                          Calle Rafael Calvo 6
# 54165         Calle Concejal Benito Martin Lozano 1
# 54610                   Calle Eugenia De Montijo 90
# 54669                      Calle Navas De Tolosa 10
# 55148                   Plaza De Agustín Gonzalez 1
# ...                                             ...
# 70107                              Calle Montesa 22
# 70465                       Calle Candido Mateos 11
# 70697                             Calle Aguileñas 1
# 70915  Paseo Rey 36 Junto Al Albergue De San Isidro
# 71248                        Calle Arturo Soria 103
#
#                   BiciMad Station                      Station Location
# 53983    General Martínez Campos        Calle Fernández de la Hoz nº 29
# 54165            Puerta de Toledo  Glorieta de la Puerta de Toledo nº 1
# 54610                    Caramuel                  Calle Caramuel nº 51
# 54669                 Jacometrezo                Calle Jacometrezo nº 3
# 55148         Marqués de Corbera       Avenida Marqués de Corbera nº 52
# ...                           ...                                   ...
# 70107            Ortega y Gasset            Calle Ortega y Gasset nº 87
# 70465           Francos Rodríguez         Calle Francos Rodríguez nº 62
# 70697                     Remonta                   Calle Azucenas nº 1
# 70915         Paseo de la Florida              Paseo de la Florida nº 8
# 71248             Carlota O’Neill           Calle Carlota O'Neill nº 32
#
# [270 rows x 5 columns]
